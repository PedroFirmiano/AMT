# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date
import csv
import calendar
import matplotlib.pyplot as plt
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.dates as mdates

## Os dados são lidos a partir do dowload feito na pagina do inmet, por isto o diretorio está como meu computador

#São selecionados dados de todos os anos de uma localidade
def importar(dados):
    y = 'C:/Users/pedro/Documents/INMET/'
    z = y + dados
    x = pd.read_csv(z, sep = ';', decimal=',', names = ['datetm', 'hora', 'precipitação', 'pressao', 'pressaoMax' , 'pressMin', 'glo_avg', 'tempBulb', 'tempPontOrv', 'tempMax', 'tempMin', 'TempOrvMax', 'TempOrvMin', 'umidade', 'ventoRajada', 'ventoVelocidade'])
    x = x[9:]

    return x
df_2000 = importar('2000/INMET_NE_BA_A401_SALVADOR_13-05-2000_A_31-12-2000.csv')
df_2001 = importar('2001/INMET_NE_BA_A401_SALVADOR_01-01-2001_A_31-12-2001.csv')
df_2002 = importar('2002/INMET_NE_BA_A401_SALVADOR_01-01-2002_A_31-12-2002.csv')
df_2003 = importar('2003/INMET_NE_BA_A401_SALVADOR_01-01-2003_A_31-12-2003.csv')
df_2004 = importar('2004/INMET_NE_BA_A401_SALVADOR_01-01-2004_A_31-12-2004.csv')
df_2005 = importar('2005/INMET_NE_BA_A401_SALVADOR_01-01-2005_A_31-12-2005.csv')
df_2006 = importar('2006/INMET_NE_BA_A401_SALVADOR_01-01-2006_A_31-12-2006.csv')
df_2007 = importar('2007/INMET_NE_BA_A401_SALVADOR_01-01-2007_A_31-12-2007.csv')
df_2008 = importar('2008/INMET_NE_BA_A401_SALVADOR_01-01-2008_A_31-12-2008.csv')
df_2009 = importar('2009/INMET_NE_BA_A401_SALVADOR_01-01-2009_A_31-12-2009.csv')
df_2010 = importar('2010/INMET_NE_BA_A401_SALVADOR_01-01-2010_A_31-12-2010.csv')
df_2011 = importar('2011/INMET_NE_BA_A401_SALVADOR_01-01-2011_A_31-12-2011.csv')
df_2012 = importar('2012/INMET_NE_BA_A401_SALVADOR_01-01-2012_A_31-12-2012.csv')
df_2013 = importar('2013/INMET_NE_BA_A401_SALVADOR_01-01-2013_A_31-12-2013.csv')
df_2014 = importar('2014/INMET_NE_BA_A401_SALVADOR_01-01-2014_A_31-12-2014.csv')
df_2015 = importar('2015/INMET_NE_BA_A401_SALVADOR_01-01-2015_A_31-12-2015.csv')
df_2016 = importar('2016/INMET_NE_BA_A401_SALVADOR_01-01-2016_A_31-12-2016.csv')
df_2017 = importar('2017/INMET_NE_BA_A401_SALVADOR_01-01-2017_A_31-12-2017.csv')
df_2018 = importar('2018/INMET_NE_BA_A401_SALVADOR_01-01-2018_A_31-12-2018.csv')


## a partir deste momento começo a trabalhar com os dados
df = pd.concat([df_2000, df_2001, df_2002, df_2003, df_2004, df_2005, df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018])

df_dt = pd.DataFrame(data=df, columns=['datetm'])
df_dt['datetm'] =  pd.to_datetime(df['datetm'], format='%Y-%m-%d %H:%M')
df.index = df_dt['datetm']



df.drop('datetm', axis = 1, inplace=True)
df.drop('hora', axis = 1, inplace=True)
df.drop('precipitação', axis = 1, inplace=True)
df.drop('pressaoMax', axis = 1, inplace=True)
df.drop('pressMin', axis = 1, inplace=True)
df.drop('ventoRajada', axis = 1, inplace=True)


df = df.reset_index(level='datetm')
df['year'] = df['datetm'].dt.year
df['month'] = df['datetm'].dt.month
df.index = df_dt['datetm']

df["glo_avg"]= df["glo_avg"].str.replace(',','.')
df['glo_avg'] = df['glo_avg'].astype(float)
df["tempBulb"]= df["tempBulb"].str.replace(',','.')
df['tempBulb'] = df['tempBulb'].astype(float)
df["tempPontOrv"]= df["tempPontOrv"].str.replace(',','.')
df['tempPontOrv'] = df['tempPontOrv'].astype(float)
df["TempOrvMax"]= df["TempOrvMax"].str.replace(',','.')
df['TempOrvMax'] = df['TempOrvMax'].astype(float)
df["TempOrvMin"]= df["TempOrvMin"].str.replace(',','.')
df['TempOrvMin'] = df['TempOrvMin'].astype(float)
df["tempMax"]= df["tempMax"].str.replace(',','.')
df['tempMax'] = df['tempMax'].astype(float)
df["tempMin"]= df["tempMin"].str.replace(',','.')
df['tempMin'] = df['tempMin'].astype(float)
df["umidade"]= df["umidade"].str.replace(',','.')
df['umidade'] = df['umidade'].astype(float)
df["ventoVelocidade"]= df["ventoVelocidade"].str.replace(',','.')
df['ventoVelocidade'] = df['ventoVelocidade'].astype(float)

df_00 = df.loc[(df.year) == 2000]
df_01 = df.loc[(df.year) == 2001]
df_02 = df.loc[(df.year) == 2002]
df_03 = df.loc[(df.year) == 2003]
df_04 = df.loc[(df.year) == 2004]
df_05 = df.loc[(df.year) == 2005]
df_06 = df.loc[(df.year) == 2006]
df_07 = df.loc[(df.year) == 2007]
df_08 = df.loc[(df.year) == 2008]
df_09 = df.loc[(df.year) == 2009]
df_10 = df.loc[(df.year) == 2010]
df_11 = df.loc[(df.year) == 2011]
df_12 = df.loc[(df.year) == 2012]
df_13 = df.loc[(df.year) == 2013]
df_14 = df.loc[(df.year) == 2014]
df_15 = df.loc[(df.year) == 2015]
df_16 = df.loc[(df.year) == 2016]
df_17 = df.loc[(df.year) == 2017]
df_18 = df.loc[(df.year) == 2018]

df_00Jan = df_00.loc[(df_00.month) == 1]
df_00Fev = df_00.loc[(df_00.month) == 2]
df_00Mar = df_00.loc[(df_00.month) == 3]
df_00Abr = df_00.loc[(df_00.month) == 4]
df_00Mai = df_00.loc[(df_00.month) == 5]
df_00Jun = df_00.loc[(df_00.month) == 6]
df_00Jul = df_00.loc[(df_00.month) == 7]
df_00Ago = df_00.loc[(df_00.month) == 8]
df_00Set = df_00.loc[(df_00.month) == 9]
df_00Out = df_00.loc[(df_00.month) == 10]
df_00Nov = df_00.loc[(df_00.month) == 11]
df_00Dez = df_00.loc[(df_00.month) == 12]


df_01Jan = df_01.loc[(df_01.month) == 1]
df_01Fev = df_01.loc[(df_01.month) == 2]
df_01Mar = df_01.loc[(df_01.month) == 3]
df_01Abr = df_01.loc[(df_01.month) == 4]
df_01Mai = df_01.loc[(df_01.month) == 5]
df_01Jun = df_01.loc[(df_01.month) == 6]
df_01Jul = df_01.loc[(df_01.month) == 7]
df_01Ago = df_01.loc[(df_01.month) == 8]
df_01Set = df_01.loc[(df_01.month) == 9]
df_01Out = df_01.loc[(df_01.month) == 10]
df_01Nov = df_01.loc[(df_01.month) == 11]
df_01Dez = df_01.loc[(df_01.month) == 12]

df_02Jan = df_02.loc[(df_02.month) == 1]
df_02Fev = df_02.loc[(df_02.month) == 2]
df_02Mar = df_02.loc[(df_02.month) == 3]
df_02Abr = df_02.loc[(df_02.month) == 4]
df_02Mai = df_02.loc[(df_02.month) == 5]
df_02Jun = df_02.loc[(df_02.month) == 6]
df_02Jul = df_02.loc[(df_02.month) == 7]
df_02Ago = df_02.loc[(df_02.month) == 8]
df_02Set = df_02.loc[(df_02.month) == 9]
df_02Out = df_02.loc[(df_02.month) == 10]
df_02Nov = df_02.loc[(df_02.month) == 11]
df_02Dez = df_02.loc[(df_02.month) == 12]

df_03Jan = df_03.loc[(df_03.month) == 1]
df_03Fev = df_03.loc[(df_03.month) == 2]
df_03Mar = df_03.loc[(df_03.month) == 3]
df_03Abr = df_03.loc[(df_03.month) == 4]
df_03Mai = df_03.loc[(df_03.month) == 5]
df_03Jun = df_03.loc[(df_03.month) == 6]
df_03Jul = df_03.loc[(df_03.month) == 7]
df_03Ago = df_03.loc[(df_03.month) == 8]
df_03Set = df_03.loc[(df_03.month) == 9]
df_03Out = df_03.loc[(df_03.month) == 10]
df_03Nov = df_03.loc[(df_03.month) == 11]
df_03Dez = df_03.loc[(df_03.month) == 12]

df_04Jan = df_04.loc[(df_04.month) == 1]
df_04Fev = df_04.loc[(df_04.month) == 2]
df_04Mar = df_04.loc[(df_04.month) == 3]
df_04Abr = df_04.loc[(df_04.month) == 4]
df_04Mai = df_04.loc[(df_04.month) == 5]
df_04Jun = df_04.loc[(df_04.month) == 6]
df_04Jul = df_04.loc[(df_04.month) == 7]
df_04Ago = df_04.loc[(df_04.month) == 8]
df_04Set = df_04.loc[(df_04.month) == 9]
df_04Out = df_04.loc[(df_04.month) == 10]
df_04Nov = df_04.loc[(df_04.month) == 11]
df_04Dez = df_04.loc[(df_04.month) == 12]

df_05Jan = df_05.loc[(df_05.month) == 1]
df_05Fev = df_05.loc[(df_05.month) == 2]
df_05Mar = df_05.loc[(df_05.month) == 3]
df_05Abr = df_05.loc[(df_05.month) == 4]
df_05Mai = df_05.loc[(df_05.month) == 5]
df_05Jun = df_05.loc[(df_05.month) == 6]
df_05Jul = df_05.loc[(df_05.month) == 7]
df_05Ago = df_05.loc[(df_05.month) == 8]
df_05Set = df_05.loc[(df_05.month) == 9]
df_05Out = df_05.loc[(df_05.month) == 10]
df_05Nov = df_05.loc[(df_05.month) == 11]
df_05Dez = df_05.loc[(df_05.month) == 12]

df_06Jan = df_06.loc[(df_06.month) == 1]
df_06Fev = df_06.loc[(df_06.month) == 2]
df_06Mar = df_06.loc[(df_06.month) == 3]
df_06Abr = df_06.loc[(df_06.month) == 4]
df_06Mai = df_06.loc[(df_06.month) == 5]
df_06Jun = df_06.loc[(df_06.month) == 6]
df_06Jul = df_06.loc[(df_06.month) == 7]
df_06Ago = df_06.loc[(df_06.month) == 8]
df_06Set = df_06.loc[(df_06.month) == 9]
df_06Out = df_06.loc[(df_06.month) == 10]
df_06Nov = df_06.loc[(df_06.month) == 11]
df_06Dez = df_06.loc[(df_06.month) == 12]

df_07Jan = df_07.loc[(df_07.month) == 1]
df_07Fev = df_07.loc[(df_07.month) == 2]
df_07Mar = df_07.loc[(df_07.month) == 3]
df_07Abr = df_07.loc[(df_07.month) == 4]
df_07Mai = df_07.loc[(df_07.month) == 5]
df_07Jun = df_07.loc[(df_07.month) == 6]
df_07Jul = df_07.loc[(df_07.month) == 7]
df_07Ago = df_07.loc[(df_07.month) == 8]
df_07Set = df_07.loc[(df_07.month) == 9]
df_07Out = df_07.loc[(df_07.month) == 10]
df_07Nov = df_07.loc[(df_07.month) == 11]
df_07Dez = df_07.loc[(df_07.month) == 12]

df_08Jan = df_08.loc[(df_08.month) == 1]
df_08Fev = df_08.loc[(df_08.month) == 2]
df_08Mar = df_08.loc[(df_08.month) == 3]
df_08Abr = df_08.loc[(df_08.month) == 4]
df_08Mai = df_08.loc[(df_08.month) == 5]
df_08Jun = df_08.loc[(df_08.month) == 6]
df_08Jul = df_08.loc[(df_08.month) == 7]
df_08Ago = df_08.loc[(df_08.month) == 8]
df_08Set = df_08.loc[(df_08.month) == 9]
df_08Out = df_08.loc[(df_08.month) == 10]
df_08Nov = df_08.loc[(df_08.month) == 11]
df_08Dez = df_08.loc[(df_08.month) == 12]

df_09Jan = df_09.loc[(df_09.month) == 1]
df_09Fev = df_09.loc[(df_09.month) == 2]
df_09Mar = df_09.loc[(df_09.month) == 3]
df_09Abr = df_09.loc[(df_09.month) == 4]
df_09Mai = df_09.loc[(df_09.month) == 5]
df_09Jun = df_09.loc[(df_09.month) == 6]
df_09Jul = df_09.loc[(df_09.month) == 7]
df_09Ago = df_09.loc[(df_09.month) == 8]
df_09Set = df_09.loc[(df_09.month) == 9]
df_09Out = df_09.loc[(df_09.month) == 10]
df_09Nov = df_09.loc[(df_09.month) == 11]
df_09Dez = df_09.loc[(df_09.month) == 12]

df_10Jan = df_10.loc[(df_10.month) == 1]
df_10Fev = df_10.loc[(df_10.month) == 2]
df_10Mar = df_10.loc[(df_10.month) == 3]
df_10Abr = df_10.loc[(df_10.month) == 4]
df_10Mai = df_10.loc[(df_10.month) == 5]
df_10Jun = df_10.loc[(df_10.month) == 6]
df_10Jul = df_10.loc[(df_10.month) == 7]
df_10Ago = df_10.loc[(df_10.month) == 8]
df_10Set = df_10.loc[(df_10.month) == 9]
df_10Out = df_10.loc[(df_10.month) == 10]
df_10Nov = df_10.loc[(df_10.month) == 11]
df_10Dez = df_10.loc[(df_10.month) == 12]

df_11Jan = df_11.loc[(df_11.month) == 1]
df_11Fev = df_11.loc[(df_11.month) == 2]
df_11Mar = df_11.loc[(df_11.month) == 3]
df_11Abr = df_11.loc[(df_11.month) == 4]
df_11Mai = df_11.loc[(df_11.month) == 5]
df_11Jun = df_11.loc[(df_11.month) == 6]
df_11Jul = df_11.loc[(df_11.month) == 7]
df_11Ago = df_11.loc[(df_11.month) == 8]
df_11Set = df_11.loc[(df_11.month) == 9]
df_11Out = df_11.loc[(df_11.month) == 10]
df_11Nov = df_11.loc[(df_11.month) == 11]
df_11Dez = df_11.loc[(df_11.month) == 12]

df_12Jan = df_12.loc[(df_12.month) == 1]
df_12Fev = df_12.loc[(df_12.month) == 2]
df_12Mar = df_12.loc[(df_12.month) == 3]
df_12Abr = df_12.loc[(df_12.month) == 4]
df_12Mai = df_12.loc[(df_12.month) == 5]
df_12Jun = df_12.loc[(df_12.month) == 6]
df_12Jul = df_12.loc[(df_12.month) == 7]
df_12Ago = df_12.loc[(df_12.month) == 8]
df_12Set = df_12.loc[(df_12.month) == 9]
df_12Out = df_12.loc[(df_12.month) == 10]
df_12Nov = df_12.loc[(df_12.month) == 11]
df_12Dez = df_12.loc[(df_12.month) == 12]

df_13Jan = df_13.loc[(df_13.month) == 1]
df_13Fev = df_13.loc[(df_13.month) == 2]
df_13Mar = df_13.loc[(df_13.month) == 3]
df_13Abr = df_13.loc[(df_13.month) == 4]
df_13Mai = df_13.loc[(df_13.month) == 5]
df_13Jun = df_13.loc[(df_13.month) == 6]
df_13Jul = df_13.loc[(df_13.month) == 7]
df_13Ago = df_13.loc[(df_13.month) == 8]
df_13Set = df_13.loc[(df_13.month) == 9]
df_13Out = df_13.loc[(df_13.month) == 10]
df_13Nov = df_13.loc[(df_13.month) == 11]
df_13Dez = df_13.loc[(df_13.month) == 12]

df_14Jan = df_14.loc[(df_14.month) == 1]
df_14Fev = df_14.loc[(df_14.month) == 2]
df_14Mar = df_14.loc[(df_14.month) == 3]
df_14Abr = df_14.loc[(df_14.month) == 4]
df_14Mai = df_14.loc[(df_14.month) == 5]
df_14Jun = df_14.loc[(df_14.month) == 6]
df_14Jul = df_14.loc[(df_14.month) == 7]
df_14Ago = df_14.loc[(df_14.month) == 8]
df_14Set = df_14.loc[(df_14.month) == 9]
df_14Out = df_14.loc[(df_14.month) == 10]
df_14Nov = df_14.loc[(df_14.month) == 11]
df_14Dez = df_14.loc[(df_14.month) == 12]

df_15Jan = df_15.loc[(df_15.month) == 1]
df_15Fev = df_15.loc[(df_15.month) == 2]
df_15Mar = df_15.loc[(df_15.month) == 3]
df_15Abr = df_15.loc[(df_15.month) == 4]
df_15Mai = df_15.loc[(df_15.month) == 5]
df_15Jun = df_15.loc[(df_15.month) == 6]
df_15Jul = df_15.loc[(df_15.month) == 7]
df_15Ago = df_15.loc[(df_15.month) == 8]
df_15Set = df_15.loc[(df_15.month) == 9]
df_15Out = df_15.loc[(df_15.month) == 10]
df_15Nov = df_15.loc[(df_15.month) == 11]
df_15Dez = df_15.loc[(df_15.month) == 12]

df_16Jan = df_16.loc[(df_16.month) == 1]
df_16Fev = df_16.loc[(df_16.month) == 2]
df_16Mar = df_16.loc[(df_16.month) == 3]
df_16Abr = df_16.loc[(df_16.month) == 4]
df_16Mai = df_16.loc[(df_16.month) == 5]
df_16Jun = df_16.loc[(df_16.month) == 6]
df_16Jul = df_16.loc[(df_16.month) == 7]
df_16Ago = df_16.loc[(df_16.month) == 8]
df_16Set = df_16.loc[(df_16.month) == 9]
df_16Out = df_16.loc[(df_16.month) == 10]
df_16Nov = df_16.loc[(df_16.month) == 11]
df_16Dez = df_16.loc[(df_16.month) == 12]

df_17Jan = df_17.loc[(df_17.month) == 1]
df_17Fev = df_17.loc[(df_17.month) == 2]
df_17Mar = df_17.loc[(df_17.month) == 3]
df_17Abr = df_17.loc[(df_17.month) == 4]
df_17Mai = df_17.loc[(df_17.month) == 5]
df_17Jun = df_17.loc[(df_17.month) == 6]
df_17Jul = df_17.loc[(df_17.month) == 7]
df_17Ago = df_17.loc[(df_17.month) == 8]
df_17Set = df_17.loc[(df_17.month) == 9]
df_17Out = df_17.loc[(df_17.month) == 10]
df_17Nov = df_17.loc[(df_17.month) == 11]
df_17Dez = df_17.loc[(df_17.month) == 12]

df_18Jan = df_18.loc[(df_18.month) == 1]
df_18Fev = df_18.loc[(df_18.month) == 2]
df_18Mar = df_18.loc[(df_18.month) == 3]
df_18Abr = df_18.loc[(df_18.month) == 4]
df_18Mai = df_18.loc[(df_18.month) == 5]
df_18Jun = df_18.loc[(df_18.month) == 6]
df_18Jul = df_18.loc[(df_18.month) == 7]
df_18Ago = df_18.loc[(df_18.month) == 8]
df_18Set = df_18.loc[(df_18.month) == 9]
df_18Out = df_18.loc[(df_18.month) == 10]
df_18Nov = df_18.loc[(df_18.month) == 11]
df_18Dez = df_18.loc[(df_18.month) == 12]

# %%
## função para a criação de um AMT 

def AMT(df_00, df_01, df_02, df_03, df_04, df_05, df_06, df_07, df_08, df_09, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, mes):
    df_dados = df.loc[(df.month) == mes]
    'função para temp min'
    def variavelTempMin(dados):
        variavel_temp = dados.loc[(dados['tempMin'] > -9998)]
        variavel_temp = variavel_temp['tempMin']
        variavel_temp = variavel_temp.resample('d').min()
        variavel_temp.dropna(how='any', inplace=True)
        variavel_temp = variavel_temp.loc[(variavel_temp != 0)]
        return variavel_temp
​
    'função para temp max'
    def variavelTempMax(dados):
        variavel_temp = dados.loc[(dados['tempMax'] > -9998 )]
        variavel_temp = variavel_temp['tempMax']
        variavel_temp = variavel_temp.resample('d').max()
        variavel_temp.dropna(how='any', inplace=True)
        variavel_temp = variavel_temp.loc[(variavel_temp != 0)]
        return variavel_temp
​
    'função para temp BulboSeco'
    def variavelTempBulbSeco(dados):
        variavel_temp = dados.loc[(dados['tempBulb']  > -9998)]
        variavel_temp = variavel_temp.loc[(variavel_temp['tempBulb']  > -9998)]
        variavel_temp = variavel_temp['tempBulb']
        variavel_temp = variavel_temp.resample('d').mean()
        variavel_temp.dropna(how='any', inplace=True)
        variavel_temp = variavel_temp.loc[(variavel_temp != 0)]
​
        return variavel_temp
​
    'função para Ponto Orv'
    def variavelTempPontoOrv(dados):
        variavel_temp = dados.loc[(dados['tempPontOrv']  > -9998)]
        variavel_temp = variavel_temp['tempPontOrv']
        variavel_temp = variavel_temp.resample('d').mean()
        variavel_temp.dropna(how='any', inplace=True)
        variavel_temp = variavel_temp.loc[(variavel_temp != 0)]
        return variavel_temp
​
​
    'função para Ponto Orv Max'
    def variavelTempPontoOrvMax(dados):
        variavel_temp = dados.loc[(dados['TempOrvMax']  > -9998)]
        variavel_temp = variavel_temp['TempOrvMax']
        variavel_temp = variavel_temp.resample('d').mean()
        variavel_temp.dropna(how='any', inplace=True)
        variavel_temp = variavel_temp.loc[(variavel_temp != 0)]
        return variavel_temp
​
    'função para Ponto Orv Min'
    def variavelTempPontoOrvMin(dados):
        variavel_temp = dados.loc[(dados['TempOrvMin']  > -9998)]
        variavel_temp = variavel_temp['TempOrvMin']    
        variavel_temp = variavel_temp.resample('d').mean()
        variavel_temp.dropna(how='any', inplace=True)
        variavel_temp = variavel_temp.loc[(variavel_temp != 0)]
        return variavel_temp
​
    'função para umid'
    def variavelUmid(dados):
        variavel_umid = dados.loc[(dados['umidade'] > -9998)]
        variavel_umid = variavel_umid['umidade']
        variavel_umid.dropna()
        variavel_umid = variavel_umid.loc[(variavel_umid != 0)]
        return variavel_umid
​
    'função para radiação Global Total diaria'
    def variavelRad(dados):
        df_remove = dados.loc[(dados['glo_avg'] > 0)]
        radTotal = df_remove['glo_avg']
        radTotal = radTotal.resample('d').sum()
        radTotal.dropna(how='any', inplace=True)
        radTotal = radTotal.loc[(radTotal > 0)]
        radTotal = radTotal.loc[(radTotal < 600000)]
        return radTotal
    
    'função para vento'
    def variavelVento(dados):
        variavel_vento = dados.loc[(dados['ventoVelocidade'] > -9998)]
        variavel_vento = variavel_vento['ventoVelocidade']
        variavel_vento.dropna()
        variavel_vento = variavel_vento.loc[(variavel_vento != 0)]
        return variavel_vento
​
​
    'funçao para Geração das ecdfs'
    def geraçãoDeECDF(dados):
        x = dados.sum()
        if x == 0:
            return 0
        else:
            cdf = dados
            ecdf = ECDF(cdf)
            return ecdf
    'variaveis temperatura minima'
    variavel_temp_min = variavelTempMin(df_dados)
    variavel_temp_min00 = variavelTempMin(df_00)
    variavel_temp_min01 = variavelTempMin(df_01)
    variavel_temp_min02 = variavelTempMin(df_02)
    variavel_temp_min03 = variavelTempMin(df_03)
    variavel_temp_min04 = variavelTempMin(df_04)
    variavel_temp_min05 = variavelTempMin(df_05)
    variavel_temp_min06 = variavelTempMin(df_06)
    variavel_temp_min07 = variavelTempMin(df_07)
    variavel_temp_min08 = variavelTempMin(df_08)
    variavel_temp_min09 = variavelTempMin(df_09)
    variavel_temp_min10 = variavelTempMin(df_10)
    variavel_temp_min11 = variavelTempMin(df_11)
    variavel_temp_min12 = variavelTempMin(df_12)
    variavel_temp_min13 = variavelTempMin(df_13)
    variavel_temp_min14 = variavelTempMin(df_14)
    variavel_temp_min15 = variavelTempMin(df_15)
    variavel_temp_min16 = variavelTempMin(df_16)
    variavel_temp_min17 = variavelTempMin(df_17)
    variavel_temp_min18 = variavelTempMin(df_18)
​
​
​
​
    'variaveis temperatura maxima'
    variavel_temp_max = variavelTempMax(df_dados)
    variavel_temp_max00 = variavelTempMax(df_00)
    variavel_temp_max01 = variavelTempMax(df_01)
    variavel_temp_max02 = variavelTempMax(df_02)
    variavel_temp_max03 = variavelTempMax(df_03)
    variavel_temp_max04 = variavelTempMax(df_04)
    variavel_temp_max05 = variavelTempMax(df_05)
    variavel_temp_max06 = variavelTempMax(df_06)
    variavel_temp_max07 = variavelTempMax(df_07)
    variavel_temp_max08 = variavelTempMax(df_08)
    variavel_temp_max09 = variavelTempMax(df_09)
    variavel_temp_max10 = variavelTempMax(df_10)
    variavel_temp_max11 = variavelTempMax(df_11)
    variavel_temp_max12 = variavelTempMax(df_12)
    variavel_temp_max13 = variavelTempMax(df_13)
    variavel_temp_max14 = variavelTempMax(df_14)
    variavel_temp_max15 = variavelTempMax(df_15)
    variavel_temp_max16 = variavelTempMax(df_16)
    variavel_temp_max17 = variavelTempMax(df_17)
    variavel_temp_max18 = variavelTempMax(df_18)
​
​
    'variaveis Temp Bulb Seco'
    variavel_bulbo_seco = variavelTempBulbSeco(df_dados)
    variavel_bulbo_seco00 = variavelTempBulbSeco(df_00)
    variavel_bulbo_seco01 = variavelTempBulbSeco(df_01)
    variavel_bulbo_seco02 = variavelTempBulbSeco(df_02)
    variavel_bulbo_seco03 = variavelTempBulbSeco(df_03)
    variavel_bulbo_seco04 = variavelTempBulbSeco(df_04)
    variavel_bulbo_seco05 = variavelTempBulbSeco(df_05)
    variavel_bulbo_seco06 = variavelTempBulbSeco(df_06)
    variavel_bulbo_seco07 = variavelTempBulbSeco(df_07)
    variavel_bulbo_seco08 = variavelTempBulbSeco(df_08)
    variavel_bulbo_seco09 = variavelTempBulbSeco(df_09)
    variavel_bulbo_seco10 = variavelTempBulbSeco(df_10)
    variavel_bulbo_seco11 = variavelTempBulbSeco(df_11)
    variavel_bulbo_seco12 = variavelTempBulbSeco(df_12)
    variavel_bulbo_seco13 = variavelTempBulbSeco(df_13)
    variavel_bulbo_seco14 = variavelTempBulbSeco(df_14)
    variavel_bulbo_seco15 = variavelTempBulbSeco(df_15)
    variavel_bulbo_seco16 = variavelTempBulbSeco(df_16)
    variavel_bulbo_seco17 = variavelTempBulbSeco(df_17)
    variavel_bulbo_seco18 = variavelTempBulbSeco(df_18)
​
​
​
​
    'variaveis Temp Ponto Orv'
    variavel_pont_orv = variavelTempPontoOrv(df_dados)
    variavel_pont_orv00 = variavelTempPontoOrv(df_00)
    variavel_pont_orv01 = variavelTempPontoOrv(df_01)
    variavel_pont_orv02 = variavelTempPontoOrv(df_02)
    variavel_pont_orv03 = variavelTempPontoOrv(df_03)
    variavel_pont_orv04 = variavelTempPontoOrv(df_04)
    variavel_pont_orv05 = variavelTempPontoOrv(df_05)
    variavel_pont_orv06 = variavelTempPontoOrv(df_06)
    variavel_pont_orv07 = variavelTempPontoOrv(df_07)
    variavel_pont_orv08 = variavelTempPontoOrv(df_08)
    variavel_pont_orv09 = variavelTempPontoOrv(df_09)
    variavel_pont_orv10 = variavelTempPontoOrv(df_10)
    variavel_pont_orv11 = variavelTempPontoOrv(df_11)
    variavel_pont_orv12 = variavelTempPontoOrv(df_12)
    variavel_pont_orv13 = variavelTempPontoOrv(df_13)
    variavel_pont_orv14 = variavelTempPontoOrv(df_14)
    variavel_pont_orv15 = variavelTempPontoOrv(df_15)
    variavel_pont_orv16 = variavelTempPontoOrv(df_16)
    variavel_pont_orv17 = variavelTempPontoOrv(df_17)
    variavel_pont_orv18 = variavelTempPontoOrv(df_18)
​
    'variaveis Temp Ponto Orv Max'
    variavel_pont_orv_max = variavelTempPontoOrvMax(df_dados)
    variavel_pont_orv_max00 = variavelTempPontoOrvMax(df_00)
    variavel_pont_orv_max01 = variavelTempPontoOrvMax(df_01)
    variavel_pont_orv_max02 = variavelTempPontoOrvMax(df_02)
    variavel_pont_orv_max03 = variavelTempPontoOrvMax(df_03)
    variavel_pont_orv_max04 = variavelTempPontoOrvMax(df_04)
    variavel_pont_orv_max05 = variavelTempPontoOrvMax(df_05)
    variavel_pont_orv_max06 = variavelTempPontoOrvMax(df_06)
    variavel_pont_orv_max07 = variavelTempPontoOrvMax(df_07)
    variavel_pont_orv_max08 = variavelTempPontoOrvMax(df_08)
    variavel_pont_orv_max09 = variavelTempPontoOrvMax(df_09)
    variavel_pont_orv_max10 = variavelTempPontoOrvMax(df_10)
    variavel_pont_orv_max11 = variavelTempPontoOrvMax(df_11)
    variavel_pont_orv_max12 = variavelTempPontoOrvMax(df_12)
    variavel_pont_orv_max13 = variavelTempPontoOrvMax(df_13)
    variavel_pont_orv_max14 = variavelTempPontoOrvMax(df_14)
    variavel_pont_orv_max15 = variavelTempPontoOrvMax(df_15)
    variavel_pont_orv_max16 = variavelTempPontoOrvMax(df_16)
    variavel_pont_orv_max17 = variavelTempPontoOrvMax(df_17)
    variavel_pont_orv_max18 = variavelTempPontoOrvMax(df_18)
​
​
    'variaveis Temp Ponto Orv'
    variavel_pont_orv_min = variavelTempPontoOrvMin(df_dados)
    variavel_pont_orv_min00 = variavelTempPontoOrvMin(df_00)
    variavel_pont_orv_min01 = variavelTempPontoOrvMin(df_01)
    variavel_pont_orv_min02 = variavelTempPontoOrvMin(df_02)
    variavel_pont_orv_min03 = variavelTempPontoOrvMin(df_03)
    variavel_pont_orv_min04 = variavelTempPontoOrvMin(df_04)
    variavel_pont_orv_min05 = variavelTempPontoOrvMin(df_05)
    variavel_pont_orv_min06 = variavelTempPontoOrvMin(df_06)
    variavel_pont_orv_min07 = variavelTempPontoOrvMin(df_07)
    variavel_pont_orv_min08 = variavelTempPontoOrvMin(df_08)
    variavel_pont_orv_min09 = variavelTempPontoOrvMin(df_09)
    variavel_pont_orv_min10 = variavelTempPontoOrvMin(df_10)
    variavel_pont_orv_min11 = variavelTempPontoOrvMin(df_11)
    variavel_pont_orv_min12 = variavelTempPontoOrvMin(df_12)
    variavel_pont_orv_min13 = variavelTempPontoOrvMin(df_13)
    variavel_pont_orv_min14 = variavelTempPontoOrvMin(df_14)
    variavel_pont_orv_min15 = variavelTempPontoOrvMin(df_15)
    variavel_pont_orv_min16 = variavelTempPontoOrvMin(df_16)
    variavel_pont_orv_min17 = variavelTempPontoOrvMin(df_17)
    variavel_pont_orv_min18 = variavelTempPontoOrvMin(df_18)
​
​
    'variaveis umidade'
    variavel_umid = variavelUmid(df_dados)
    variavel_umid00 = variavelUmid(df_00)
    variavel_umid01 = variavelUmid(df_01)
    variavel_umid02 = variavelUmid(df_02)
    variavel_umid03 = variavelUmid(df_03)
    variavel_umid04 = variavelUmid(df_04)
    variavel_umid05 = variavelUmid(df_05)
    variavel_umid06 = variavelUmid(df_06)
    variavel_umid07 = variavelUmid(df_07)
    variavel_umid08 = variavelUmid(df_08)
    variavel_umid09 = variavelUmid(df_05)
    variavel_umid10 = variavelUmid(df_10)
    variavel_umid11 = variavelUmid(df_11)
    variavel_umid12 = variavelUmid(df_12)
    variavel_umid13 = variavelUmid(df_13)
    variavel_umid14 = variavelUmid(df_14)
    variavel_umid15 = variavelUmid(df_15)
    variavel_umid16 = variavelUmid(df_16)
    variavel_umid17 = variavelUmid(df_17)
    variavel_umid18 = variavelUmid(df_18)
​
​
    'variavel radiação global'
    variavel_radiação = variavelRad(df_dados)
    variavel_radiação00 = variavelRad(df_00)
    variavel_radiação01 = variavelRad(df_01)
    variavel_radiação02 = variavelRad(df_02)
    variavel_radiação03 = variavelRad(df_03)
    variavel_radiação04 = variavelRad(df_04)
    variavel_radiação05 = variavelRad(df_05)
    variavel_radiação06 = variavelRad(df_06)
    variavel_radiação07 = variavelRad(df_07)
    variavel_radiação08 = variavelRad(df_08)
    variavel_radiação09 = variavelRad(df_09)
    variavel_radiação10 = variavelRad(df_10)
    variavel_radiação11 = variavelRad(df_11)
    variavel_radiação12 = variavelRad(df_12)
    variavel_radiação13 = variavelRad(df_13)
    variavel_radiação14 = variavelRad(df_14)
    variavel_radiação15 = variavelRad(df_15)
    variavel_radiação16 = variavelRad(df_16)
    variavel_radiação17 = variavelRad(df_17)
    variavel_radiação18 = variavelRad(df_18)
    
    'variavel vento'
    variavel_vento = variavelVento(df_dados)
    variavel_vento00 = variavelVento(df_00)
    variavel_vento01 = variavelVento(df_01)
    variavel_vento02 = variavelVento(df_02)
    variavel_vento03 = variavelVento(df_03)
    variavel_vento04 = variavelVento(df_04)
    variavel_vento05 = variavelVento(df_05)
    variavel_vento06 = variavelVento(df_06)
    variavel_vento07 = variavelVento(df_07)
    variavel_vento08 = variavelVento(df_08)
    variavel_vento09 = variavelVento(df_09)
    variavel_vento10 = variavelVento(df_10)
    variavel_vento11 = variavelVento(df_11)
    variavel_vento12 = variavelVento(df_12)
    variavel_vento13 = variavelVento(df_13)
    variavel_vento14 = variavelVento(df_14)
    variavel_vento15 = variavelVento(df_15)
    variavel_vento16 = variavelVento(df_16)
    variavel_vento17 = variavelVento(df_17)
    variavel_vento18 = variavelVento(df_18)
​
​
    'ecdf por variavel'
​
    'ecdf radiação'
    ecdf_Radiação = geraçãoDeECDF(variavel_radiação)
    ecdf_Radiação00 = geraçãoDeECDF(variavel_radiação00)
    ecdf_Radiação01 = geraçãoDeECDF(variavel_radiação01)
    ecdf_Radiação02 = geraçãoDeECDF(variavel_radiação02)
    ecdf_Radiação03 = geraçãoDeECDF(variavel_radiação03)
    ecdf_Radiação04 = geraçãoDeECDF(variavel_radiação04)
    ecdf_Radiação05 = geraçãoDeECDF(variavel_radiação05)
    ecdf_Radiação06 = geraçãoDeECDF(variavel_radiação06)
    ecdf_Radiação07 = geraçãoDeECDF(variavel_radiação07)
    ecdf_Radiação08 = geraçãoDeECDF(variavel_radiação08)
    ecdf_Radiação09 = geraçãoDeECDF(variavel_radiação09)
    ecdf_Radiação10 = geraçãoDeECDF(variavel_radiação10)
    ecdf_Radiação11 = geraçãoDeECDF(variavel_radiação11)
    ecdf_Radiação12 = geraçãoDeECDF(variavel_radiação12)
    ecdf_Radiação13 = geraçãoDeECDF(variavel_radiação13)
    ecdf_Radiação14 = geraçãoDeECDF(variavel_radiação14)
    ecdf_Radiação15 = geraçãoDeECDF(variavel_radiação15)
    ecdf_Radiação16 = geraçãoDeECDF(variavel_radiação16)
    ecdf_Radiação17 = geraçãoDeECDF(variavel_radiação17)
    ecdf_Radiação18 = geraçãoDeECDF(variavel_radiação18)
​
​
    'ecdf umidade'
    ecdf_umidade = geraçãoDeECDF(variavel_umid)
    ecdf_umidade00 = geraçãoDeECDF(variavel_umid00)
    ecdf_umidade01 = geraçãoDeECDF(variavel_umid01)
    ecdf_umidade02 = geraçãoDeECDF(variavel_umid02)
    ecdf_umidade03 = geraçãoDeECDF(variavel_umid03)
    ecdf_umidade04 = geraçãoDeECDF(variavel_umid04)
    ecdf_umidade05 = geraçãoDeECDF(variavel_umid05)
    ecdf_umidade06 = geraçãoDeECDF(variavel_umid06)
    ecdf_umidade07 = geraçãoDeECDF(variavel_umid07)
    ecdf_umidade08 = geraçãoDeECDF(variavel_umid08)
    ecdf_umidade09 = geraçãoDeECDF(variavel_umid09)
    ecdf_umidade10 = geraçãoDeECDF(variavel_umid10)
    ecdf_umidade11 = geraçãoDeECDF(variavel_umid11)
    ecdf_umidade12 = geraçãoDeECDF(variavel_umid12)
    ecdf_umidade13 = geraçãoDeECDF(variavel_umid13)
    ecdf_umidade14 = geraçãoDeECDF(variavel_umid14)
    ecdf_umidade15 = geraçãoDeECDF(variavel_umid15)
    ecdf_umidade16 = geraçãoDeECDF(variavel_umid16)
    ecdf_umidade17 = geraçãoDeECDF(variavel_umid17)
    ecdf_umidade18 = geraçãoDeECDF(variavel_umid18)
​
​
​
​
    'ecdf temp min'
    ecdf_temp_min = geraçãoDeECDF(variavel_temp_min)
    ecdf_temp_min00 = geraçãoDeECDF(variavel_temp_min00)
    ecdf_temp_min01 = geraçãoDeECDF(variavel_temp_min01)
    ecdf_temp_min02 = geraçãoDeECDF(variavel_temp_min02)
    ecdf_temp_min03 = geraçãoDeECDF(variavel_temp_min03)
    ecdf_temp_min04 = geraçãoDeECDF(variavel_temp_min04)
    ecdf_temp_min05 = geraçãoDeECDF(variavel_temp_min05)
    ecdf_temp_min06 = geraçãoDeECDF(variavel_temp_min06)
    ecdf_temp_min07 = geraçãoDeECDF(variavel_temp_min07)
    ecdf_temp_min08 = geraçãoDeECDF(variavel_temp_min08)
    ecdf_temp_min09 = geraçãoDeECDF(variavel_temp_min09)
    ecdf_temp_min10 = geraçãoDeECDF(variavel_temp_min10)
    ecdf_temp_min11 = geraçãoDeECDF(variavel_temp_min11)
    ecdf_temp_min12 = geraçãoDeECDF(variavel_temp_min12)
    ecdf_temp_min13 = geraçãoDeECDF(variavel_temp_min13)
    ecdf_temp_min14 = geraçãoDeECDF(variavel_temp_min14)
    ecdf_temp_min15 = geraçãoDeECDF(variavel_temp_min15)
    ecdf_temp_min16 = geraçãoDeECDF(variavel_temp_min16)
    ecdf_temp_min17 = geraçãoDeECDF(variavel_temp_min17)
    ecdf_temp_min18 = geraçãoDeECDF(variavel_temp_min18)
​
​
    'ecdf temp max'
    ecdf_temp_max = geraçãoDeECDF(variavel_temp_max)
    ecdf_temp_max00 = geraçãoDeECDF(variavel_temp_max00)
    ecdf_temp_max01 = geraçãoDeECDF(variavel_temp_max01)
    ecdf_temp_max02 = geraçãoDeECDF(variavel_temp_max02)
    ecdf_temp_max03 = geraçãoDeECDF(variavel_temp_max03)
    ecdf_temp_max04 = geraçãoDeECDF(variavel_temp_max04)
    ecdf_temp_max05 = geraçãoDeECDF(variavel_temp_max05)
    ecdf_temp_max05 = geraçãoDeECDF(variavel_temp_max05)
    ecdf_temp_max06 = geraçãoDeECDF(variavel_temp_max06)
    ecdf_temp_max07 = geraçãoDeECDF(variavel_temp_max07)
    ecdf_temp_max08 = geraçãoDeECDF(variavel_temp_max08)
    ecdf_temp_max09 = geraçãoDeECDF(variavel_temp_max09)
    ecdf_temp_max10 = geraçãoDeECDF(variavel_temp_max10)
    ecdf_temp_max11 = geraçãoDeECDF(variavel_temp_max11)
    ecdf_temp_max12 = geraçãoDeECDF(variavel_temp_max12)
    ecdf_temp_max13 = geraçãoDeECDF(variavel_temp_max13)
    ecdf_temp_max14 = geraçãoDeECDF(variavel_temp_max14)
    ecdf_temp_max15 = geraçãoDeECDF(variavel_temp_max15)
    ecdf_temp_max16 = geraçãoDeECDF(variavel_temp_max16)
    ecdf_temp_max17 = geraçãoDeECDF(variavel_temp_max17)
    ecdf_temp_max18 = geraçãoDeECDF(variavel_temp_max18)
​
    'ecdf temp Bulb seco'
    ecdf_temp_bulb_seco = geraçãoDeECDF(variavel_bulbo_seco)
    ecdf_temp_bulb_seco00 = geraçãoDeECDF(variavel_bulbo_seco00)
    ecdf_temp_bulb_seco01 = geraçãoDeECDF(variavel_bulbo_seco01)
    ecdf_temp_bulb_seco02 = geraçãoDeECDF(variavel_bulbo_seco02)
    ecdf_temp_bulb_seco03 = geraçãoDeECDF(variavel_bulbo_seco03)
    ecdf_temp_bulb_seco04 = geraçãoDeECDF(variavel_bulbo_seco04)
    ecdf_temp_bulb_seco05 = geraçãoDeECDF(variavel_bulbo_seco05)
    ecdf_temp_bulb_seco06 = geraçãoDeECDF(variavel_bulbo_seco06)
    ecdf_temp_bulb_seco07 = geraçãoDeECDF(variavel_bulbo_seco07)
    ecdf_temp_bulb_seco08 = geraçãoDeECDF(variavel_bulbo_seco08)
    ecdf_temp_bulb_seco09 = geraçãoDeECDF(variavel_bulbo_seco09)
    ecdf_temp_bulb_seco10 = geraçãoDeECDF(variavel_bulbo_seco10)
    ecdf_temp_bulb_seco11 = geraçãoDeECDF(variavel_bulbo_seco11)
    ecdf_temp_bulb_seco12 = geraçãoDeECDF(variavel_bulbo_seco12)
    ecdf_temp_bulb_seco13 = geraçãoDeECDF(variavel_bulbo_seco13)
    ecdf_temp_bulb_seco14 = geraçãoDeECDF(variavel_bulbo_seco14)
    ecdf_temp_bulb_seco15 = geraçãoDeECDF(variavel_bulbo_seco15)
    ecdf_temp_bulb_seco16 = geraçãoDeECDF(variavel_bulbo_seco16)
    ecdf_temp_bulb_seco17 = geraçãoDeECDF(variavel_bulbo_seco17)
    ecdf_temp_bulb_seco18 = geraçãoDeECDF(variavel_bulbo_seco18)
​
    'ecdf temp Ponto de orvalho'
    ecdf_temp_pont_orv = geraçãoDeECDF(variavel_pont_orv)
    ecdf_temp_pont_orv00 = geraçãoDeECDF(variavel_pont_orv00)
    ecdf_temp_pont_orv01 = geraçãoDeECDF(variavel_pont_orv01)
    ecdf_temp_pont_orv02 = geraçãoDeECDF(variavel_pont_orv02)
    ecdf_temp_pont_orv03 = geraçãoDeECDF(variavel_pont_orv03)
    ecdf_temp_pont_orv04 = geraçãoDeECDF(variavel_pont_orv04)
    ecdf_temp_pont_orv05 = geraçãoDeECDF(variavel_pont_orv05)
    ecdf_temp_pont_orv06 = geraçãoDeECDF(variavel_pont_orv06)
    ecdf_temp_pont_orv07 = geraçãoDeECDF(variavel_pont_orv07)
    ecdf_temp_pont_orv08 = geraçãoDeECDF(variavel_pont_orv08)
    ecdf_temp_pont_orv09 = geraçãoDeECDF(variavel_pont_orv09)
    ecdf_temp_pont_orv10 = geraçãoDeECDF(variavel_pont_orv10)
    ecdf_temp_pont_orv11 = geraçãoDeECDF(variavel_pont_orv11)
    ecdf_temp_pont_orv12 = geraçãoDeECDF(variavel_pont_orv12)
    ecdf_temp_pont_orv13 = geraçãoDeECDF(variavel_pont_orv13)
    ecdf_temp_pont_orv14 = geraçãoDeECDF(variavel_pont_orv14)
    ecdf_temp_pont_orv15 = geraçãoDeECDF(variavel_pont_orv15)
    ecdf_temp_pont_orv16 = geraçãoDeECDF(variavel_pont_orv16)
    ecdf_temp_pont_orv17 = geraçãoDeECDF(variavel_pont_orv17)
    ecdf_temp_pont_orv18 = geraçãoDeECDF(variavel_pont_orv18)
​
​
    'ecdf temp Ponto de orvalho max'
    ecdf_temp_pont_orv_max = geraçãoDeECDF(variavel_pont_orv_max)
    ecdf_temp_pont_orv_max00 = geraçãoDeECDF(variavel_pont_orv_max00)
    ecdf_temp_pont_orv_max01 = geraçãoDeECDF(variavel_pont_orv_max01)
    ecdf_temp_pont_orv_max02 = geraçãoDeECDF(variavel_pont_orv_max02)
    ecdf_temp_pont_orv_max03 = geraçãoDeECDF(variavel_pont_orv_max03)
    ecdf_temp_pont_orv_max04 = geraçãoDeECDF(variavel_pont_orv_max04)
    ecdf_temp_pont_orv_max05 = geraçãoDeECDF(variavel_pont_orv_max05)
    ecdf_temp_pont_orv_max06 = geraçãoDeECDF(variavel_pont_orv_max06)
    ecdf_temp_pont_orv_max07 = geraçãoDeECDF(variavel_pont_orv_max07)
    ecdf_temp_pont_orv_max08 = geraçãoDeECDF(variavel_pont_orv_max08)
    ecdf_temp_pont_orv_max09 = geraçãoDeECDF(variavel_pont_orv_max09)
    ecdf_temp_pont_orv_max10 = geraçãoDeECDF(variavel_pont_orv_max10)
    ecdf_temp_pont_orv_max11 = geraçãoDeECDF(variavel_pont_orv_max11)
    ecdf_temp_pont_orv_max12 = geraçãoDeECDF(variavel_pont_orv_max12)
    ecdf_temp_pont_orv_max13 = geraçãoDeECDF(variavel_pont_orv_max13)
    ecdf_temp_pont_orv_max14 = geraçãoDeECDF(variavel_pont_orv_max14)
    ecdf_temp_pont_orv_max15 = geraçãoDeECDF(variavel_pont_orv_max15)
    ecdf_temp_pont_orv_max16 = geraçãoDeECDF(variavel_pont_orv_max16)
    ecdf_temp_pont_orv_max17 = geraçãoDeECDF(variavel_pont_orv_max17)
    ecdf_temp_pont_orv_max18 = geraçãoDeECDF(variavel_pont_orv_max18)
​
    'ecdf temp Ponto de orvalho max'
    ecdf_temp_pont_orv_min = geraçãoDeECDF(variavel_pont_orv_min)
    ecdf_temp_pont_orv_min00 = geraçãoDeECDF(variavel_pont_orv_min00)
    ecdf_temp_pont_orv_min01 = geraçãoDeECDF(variavel_pont_orv_min01)
    ecdf_temp_pont_orv_min02 = geraçãoDeECDF(variavel_pont_orv_min02)
    ecdf_temp_pont_orv_min03 = geraçãoDeECDF(variavel_pont_orv_min03)
    ecdf_temp_pont_orv_min04 = geraçãoDeECDF(variavel_pont_orv_min04)
    ecdf_temp_pont_orv_min05 = geraçãoDeECDF(variavel_pont_orv_min05)
    ecdf_temp_pont_orv_min06 = geraçãoDeECDF(variavel_pont_orv_min06)
    ecdf_temp_pont_orv_min07 = geraçãoDeECDF(variavel_pont_orv_min07)
    ecdf_temp_pont_orv_min08 = geraçãoDeECDF(variavel_pont_orv_min08)
    ecdf_temp_pont_orv_min09 = geraçãoDeECDF(variavel_pont_orv_min09)
    ecdf_temp_pont_orv_min10 = geraçãoDeECDF(variavel_pont_orv_min10)
    ecdf_temp_pont_orv_min11 = geraçãoDeECDF(variavel_pont_orv_min11)
    ecdf_temp_pont_orv_min12 = geraçãoDeECDF(variavel_pont_orv_min12)
    ecdf_temp_pont_orv_min13 = geraçãoDeECDF(variavel_pont_orv_min13)
    ecdf_temp_pont_orv_min14 = geraçãoDeECDF(variavel_pont_orv_min14)
    ecdf_temp_pont_orv_min15 = geraçãoDeECDF(variavel_pont_orv_min15)
    ecdf_temp_pont_orv_min16 = geraçãoDeECDF(variavel_pont_orv_min16)
    ecdf_temp_pont_orv_min17 = geraçãoDeECDF(variavel_pont_orv_min17)
    ecdf_temp_pont_orv_min18 = geraçãoDeECDF(variavel_pont_orv_min18)
    
    'ecdf vento'
    ecdf_vento = geraçãoDeECDF(variavel_vento)
    ecdf_vento00 = geraçãoDeECDF(variavel_vento00)
    ecdf_vento01 = geraçãoDeECDF(variavel_vento01)
    ecdf_vento02 = geraçãoDeECDF(variavel_vento02)
    ecdf_vento03 = geraçãoDeECDF(variavel_vento03)
    ecdf_vento04 = geraçãoDeECDF(variavel_vento04)
    ecdf_vento05 = geraçãoDeECDF(variavel_vento05)
    ecdf_vento06 = geraçãoDeECDF(variavel_vento06)
    ecdf_vento07 = geraçãoDeECDF(variavel_vento07)
    ecdf_vento08 = geraçãoDeECDF(variavel_vento08)
    ecdf_vento09 = geraçãoDeECDF(variavel_vento09)
    ecdf_vento10 = geraçãoDeECDF(variavel_vento10)
    ecdf_vento11 = geraçãoDeECDF(variavel_vento11)
    ecdf_vento12 = geraçãoDeECDF(variavel_vento12)
    ecdf_vento13 = geraçãoDeECDF(variavel_vento13)
    ecdf_vento14 = geraçãoDeECDF(variavel_vento14)
    ecdf_vento15 = geraçãoDeECDF(variavel_vento15)
    ecdf_vento16 = geraçãoDeECDF(variavel_vento16)
    ecdf_vento17 = geraçãoDeECDF(variavel_vento17)
    ecdf_vento18 = geraçãoDeECDF(variavel_vento18)    
    
    valores_rad = ecdf_Radiação(np.arange(variavel_radiação.min(), variavel_radiação.max(), 1))
    valores_umid = ecdf_umidade(np.arange(variavel_umid.min(), variavel_umid.max(), 0.2))
    valores_temp_min = ecdf_temp_min(np.arange(variavel_temp_min.min(), variavel_temp_min.max(), 0.2))
    valores_temp_max = ecdf_temp_max(np.arange(variavel_temp_max.min(), variavel_temp_max.max(), 0.2))
    valores_temp_bulbo_seco = ecdf_temp_bulb_seco(np.arange(variavel_bulbo_seco.min(), variavel_bulbo_seco.max(), 0.2))
    valores_temp_pont_orv_max = ecdf_temp_pont_orv_max(np.arange(variavel_pont_orv_max.min(), variavel_pont_orv_max.max(), 0.2))
    valores_temp_pont_orv_min = ecdf_temp_pont_orv_min(np.arange(variavel_pont_orv_min.min(), variavel_pont_orv_min.max(), 0.2))
    valores_temp_pont_orv = ecdf_temp_pont_orv(np.arange(variavel_pont_orv.min(), variavel_pont_orv.max(), 0.2))
    valores_vento = ecdf_vento(np.arange(variavel_vento.min(), variavel_vento.max(), 0.2))
    'funçoes que calculam as diferenças'
​
    'para temperatura'
    def calculosDeDiferençaTemperatura(ecdfDoAno, variavel, valoresLongaData):
        if ecdfDoAno == 0:
            return 100
        else:
            valor = ecdfDoAno(np.arange(variavel.min(), variavel.max(), 0.2))
            dif = abs(valoresLongaData - valor)
            media = dif.sum() / dif.size
            return media
​
    'para umidade'
    def calculosDeDiferençaUmid(ecdfDoAno, valoresLongaData):
        if ecdfDoAno == 0:
            return 100
        else:
            valor = ecdfDoAno(np.arange(variavel_umid.min(), variavel_umid.max(), 0.2))
            dif = abs(valoresLongaData - valor)
            media = dif.sum() / dif.size
            return media
​
    'para radiação'
    def calculosDeDiferençaRadiação(ecdfDoAno, variavel, valoresLongaData):
        if ecdfDoAno == 0:
            return 100
        else:
            valor = ecdfDoAno(np.arange(variavel.min(), variavel.max(), 1))
            dif = abs(valoresLongaData - valor)
            media = dif.sum() / dif.size
            return media
        
        'para vento'
    def calculosDeDiferençaVento(ecdfDoAno, valoresLongaData):
        if ecdfDoAno == 0:
            return 100
        else:
            valor = ecdfDoAno(np.arange(variavel_vento.min(), variavel_vento.max(), 0.2))
            dif = abs(valoresLongaData - valor)
            media = dif.sum() / dif.size
            return media
​
    'dif temperatura minima da longa data'
    dif_temp_min00 = calculosDeDiferençaTemperatura(ecdf_temp_min00, variavel_temp_min, valores_temp_min)
    dif_temp_min01 = calculosDeDiferençaTemperatura(ecdf_temp_min01, variavel_temp_min, valores_temp_min)
    dif_temp_min02 = calculosDeDiferençaTemperatura(ecdf_temp_min02, variavel_temp_min, valores_temp_min)
    dif_temp_min03 = calculosDeDiferençaTemperatura(ecdf_temp_min03, variavel_temp_min, valores_temp_min)
    dif_temp_min04 = calculosDeDiferençaTemperatura(ecdf_temp_min04, variavel_temp_min, valores_temp_min)
    dif_temp_min05 = calculosDeDiferençaTemperatura(ecdf_temp_min05, variavel_temp_min, valores_temp_min)
    dif_temp_min06 = calculosDeDiferençaTemperatura(ecdf_temp_min06, variavel_temp_min, valores_temp_min)
    dif_temp_min07 = calculosDeDiferençaTemperatura(ecdf_temp_min07, variavel_temp_min, valores_temp_min)
    dif_temp_min08 = calculosDeDiferençaTemperatura(ecdf_temp_min08, variavel_temp_min, valores_temp_min)
    dif_temp_min09 = calculosDeDiferençaTemperatura(ecdf_temp_min09, variavel_temp_min, valores_temp_min)
    dif_temp_min10 = calculosDeDiferençaTemperatura(ecdf_temp_min10, variavel_temp_min, valores_temp_min)
    dif_temp_min11 = calculosDeDiferençaTemperatura(ecdf_temp_min11, variavel_temp_min, valores_temp_min)
    dif_temp_min12 = calculosDeDiferençaTemperatura(ecdf_temp_min12, variavel_temp_min, valores_temp_min)
    dif_temp_min13 = calculosDeDiferençaTemperatura(ecdf_temp_min13, variavel_temp_min, valores_temp_min)
    dif_temp_min14 = calculosDeDiferençaTemperatura(ecdf_temp_min14, variavel_temp_min, valores_temp_min)
    dif_temp_min15 = calculosDeDiferençaTemperatura(ecdf_temp_min15, variavel_temp_min, valores_temp_min)
    dif_temp_min16 = calculosDeDiferençaTemperatura(ecdf_temp_min16, variavel_temp_min, valores_temp_min)
    dif_temp_min17 = calculosDeDiferençaTemperatura(ecdf_temp_min17, variavel_temp_min, valores_temp_min)
    dif_temp_min18 = calculosDeDiferençaTemperatura(ecdf_temp_min18, variavel_temp_min, valores_temp_min)
​
​
    'dif temperatura maxima da longa data'
    dif_temp_max00 = calculosDeDiferençaTemperatura(ecdf_temp_max00, variavel_temp_max, valores_temp_max)
    dif_temp_max01 = calculosDeDiferençaTemperatura(ecdf_temp_max01, variavel_temp_max, valores_temp_max)
    dif_temp_max02 = calculosDeDiferençaTemperatura(ecdf_temp_max02, variavel_temp_max, valores_temp_max)
    dif_temp_max03 = calculosDeDiferençaTemperatura(ecdf_temp_max03, variavel_temp_max, valores_temp_max)
    dif_temp_max04 = calculosDeDiferençaTemperatura(ecdf_temp_max04, variavel_temp_max, valores_temp_max)
    dif_temp_max05 = calculosDeDiferençaTemperatura(ecdf_temp_max05, variavel_temp_max, valores_temp_max)
    dif_temp_max06 = calculosDeDiferençaTemperatura(ecdf_temp_max06, variavel_temp_max, valores_temp_max)
    dif_temp_max07 = calculosDeDiferençaTemperatura(ecdf_temp_max07, variavel_temp_max, valores_temp_max)
    dif_temp_max08 = calculosDeDiferençaTemperatura(ecdf_temp_max08, variavel_temp_max, valores_temp_max)
    dif_temp_max09 = calculosDeDiferençaTemperatura(ecdf_temp_max09, variavel_temp_max, valores_temp_max)
    dif_temp_max10 = calculosDeDiferençaTemperatura(ecdf_temp_max10, variavel_temp_max, valores_temp_max)
    dif_temp_max11 = calculosDeDiferençaTemperatura(ecdf_temp_max11, variavel_temp_max, valores_temp_max)
    dif_temp_max12 = calculosDeDiferençaTemperatura(ecdf_temp_max12, variavel_temp_max, valores_temp_max)
    dif_temp_max13 = calculosDeDiferençaTemperatura(ecdf_temp_max13, variavel_temp_max, valores_temp_max)
    dif_temp_max14 = calculosDeDiferençaTemperatura(ecdf_temp_max14, variavel_temp_max, valores_temp_max)
    dif_temp_max15 = calculosDeDiferençaTemperatura(ecdf_temp_max15, variavel_temp_max, valores_temp_max)
    dif_temp_max16 = calculosDeDiferençaTemperatura(ecdf_temp_max16, variavel_temp_max, valores_temp_max)
    dif_temp_max17 = calculosDeDiferençaTemperatura(ecdf_temp_max17, variavel_temp_max, valores_temp_max)
    dif_temp_max18 = calculosDeDiferençaTemperatura(ecdf_temp_max18, variavel_temp_max, valores_temp_max)
​
    'dif radiação total diaria da longa data'
    dif_rad00 = calculosDeDiferençaRadiação(ecdf_Radiação00, variavel_radiação, valores_rad)
    dif_rad01 = calculosDeDiferençaRadiação(ecdf_Radiação01, variavel_radiação, valores_rad)
    dif_rad02 = calculosDeDiferençaRadiação(ecdf_Radiação02, variavel_radiação, valores_rad)
    dif_rad03 = calculosDeDiferençaRadiação(ecdf_Radiação03, variavel_radiação, valores_rad)
    dif_rad04 = calculosDeDiferençaRadiação(ecdf_Radiação04, variavel_radiação, valores_rad)
    dif_rad05 = calculosDeDiferençaRadiação(ecdf_Radiação05, variavel_radiação, valores_rad)
    dif_rad06 = calculosDeDiferençaRadiação(ecdf_Radiação06, variavel_radiação, valores_rad)
    dif_rad07 = calculosDeDiferençaRadiação(ecdf_Radiação07, variavel_radiação, valores_rad)
    dif_rad08 = calculosDeDiferençaRadiação(ecdf_Radiação08, variavel_radiação, valores_rad)
    dif_rad09 = calculosDeDiferençaRadiação(ecdf_Radiação09, variavel_radiação, valores_rad)
    dif_rad10 = calculosDeDiferençaRadiação(ecdf_Radiação10, variavel_radiação, valores_rad)
    dif_rad11 = calculosDeDiferençaRadiação(ecdf_Radiação11, variavel_radiação, valores_rad)
    dif_rad12 = calculosDeDiferençaRadiação(ecdf_Radiação12, variavel_radiação, valores_rad)
    dif_rad13 = calculosDeDiferençaRadiação(ecdf_Radiação13, variavel_radiação, valores_rad)
    dif_rad14 = calculosDeDiferençaRadiação(ecdf_Radiação14, variavel_radiação, valores_rad)
    dif_rad15 = calculosDeDiferençaRadiação(ecdf_Radiação15, variavel_radiação, valores_rad)
    dif_rad16 = calculosDeDiferençaRadiação(ecdf_Radiação16, variavel_radiação, valores_rad)
    dif_rad17 = calculosDeDiferençaRadiação(ecdf_Radiação17, variavel_radiação, valores_rad)
    dif_rad18 = calculosDeDiferençaRadiação(ecdf_Radiação18, variavel_radiação, valores_rad)
​
​
    'dif umidade total diaria da longa data'
    dif_umid00 = calculosDeDiferençaUmid(ecdf_umidade00, valores_umid)
    dif_umid01 = calculosDeDiferençaUmid(ecdf_umidade01, valores_umid)
    dif_umid02 = calculosDeDiferençaUmid(ecdf_umidade02, valores_umid)
    dif_umid03 = calculosDeDiferençaUmid(ecdf_umidade03, valores_umid)
    dif_umid04 = calculosDeDiferençaUmid(ecdf_umidade04, valores_umid)
    dif_umid05 = calculosDeDiferençaUmid(ecdf_umidade05, valores_umid)
    dif_umid06 = calculosDeDiferençaUmid(ecdf_umidade06, valores_umid)
    dif_umid07 = calculosDeDiferençaUmid(ecdf_umidade07, valores_umid)
    dif_umid08 = calculosDeDiferençaUmid(ecdf_umidade08, valores_umid)
    dif_umid09 = calculosDeDiferençaUmid(ecdf_umidade09, valores_umid)
    dif_umid10 = calculosDeDiferençaUmid(ecdf_umidade10, valores_umid)
    dif_umid11 = calculosDeDiferençaUmid(ecdf_umidade11, valores_umid)
    dif_umid12 = calculosDeDiferençaUmid(ecdf_umidade12, valores_umid)
    dif_umid13 = calculosDeDiferençaUmid(ecdf_umidade13, valores_umid)
    dif_umid14 = calculosDeDiferençaUmid(ecdf_umidade14, valores_umid)
    dif_umid15 = calculosDeDiferençaUmid(ecdf_umidade15, valores_umid)
    dif_umid16 = calculosDeDiferençaUmid(ecdf_umidade16, valores_umid)
    dif_umid17 = calculosDeDiferençaUmid(ecdf_umidade17, valores_umid)
    dif_umid18 = calculosDeDiferençaUmid(ecdf_umidade18, valores_umid)
​
​
    'dif temperatura Bulbo Seco da longa data'
    dif_temp_bulb_seco00 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco00, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco01 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco01, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco02 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco02, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco03 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco03, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco04 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco04, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco05 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco05, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco06 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco06, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco07 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco07, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco08 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco08, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco09 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco09, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco10 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco10, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco11 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco11, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco12 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco12, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco13 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco13, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco14 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco14, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco15 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco15, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco16 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco16, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco17 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco17, variavel_bulbo_seco, valores_temp_bulbo_seco)
    dif_temp_bulb_seco18 = calculosDeDiferençaTemperatura(ecdf_temp_bulb_seco18, variavel_bulbo_seco, valores_temp_bulbo_seco)
​
    'dif temperatura pont orva max da longa data'
    dif_temp_pont_orv00 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max00, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv01 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max01, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv02 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max02, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv03 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max03, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv04 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max04, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv05 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max05, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv06 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max06, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv07 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max07, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv08 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max08, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv09 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max09, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv10 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max10, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv11 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max11, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv12 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max12, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv13 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max13, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv14 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max14, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv15 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max15, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv16 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max16, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv17 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max17, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv18 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max18, variavel_pont_orv_max, valores_temp_pont_orv_max)
​
    'dif temperatura ponto de orv min da longa data'
    dif_temp_pont_orv_min00 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min00, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min01 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min01, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min02 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min02, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min03 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min03, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min04 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min04, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min05 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min05, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min06 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min06, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min07 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min07, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min08 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min08, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min09 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min09, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min10 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min10, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min11 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min11, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min12 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min12, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min13 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min13, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min14 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min14, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min15 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min15, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min16 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min16, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min17 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min17, variavel_pont_orv_min, valores_temp_pont_orv_min)
    dif_temp_pont_orv_min18 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_min18, variavel_pont_orv_min, valores_temp_pont_orv_min)
​
    'dif temperatura ponto de orv min da longa data'
    dif_temp_pont_orv_max00 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max00, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max01 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max01, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max02 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max02, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max03 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max03, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max04 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max04, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max05 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max05, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max06 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max06, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max07 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max07, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max08 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max08, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max09 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max09, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max10 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max10, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max11 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max11, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max12 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max12, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max13 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max13, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max14 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max14, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max15 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max15, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max16 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max16, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max17 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max17, variavel_pont_orv_max, valores_temp_pont_orv_max)
    dif_temp_pont_orv_max18 = calculosDeDiferençaTemperatura(ecdf_temp_pont_orv_max18, variavel_pont_orv_max, valores_temp_pont_orv_max)
    
    'dif umidade total diaria da longa data'
    dif_vento00 = calculosDeDiferençaVento(ecdf_vento00, valores_vento)
    dif_vento01 = calculosDeDiferençaVento(ecdf_vento01, valores_vento)
    dif_vento02 = calculosDeDiferençaVento(ecdf_vento02, valores_vento)
    dif_vento03 = calculosDeDiferençaVento(ecdf_vento03, valores_vento)
    dif_vento04 = calculosDeDiferençaVento(ecdf_vento04, valores_vento)
    dif_vento05 = calculosDeDiferençaVento(ecdf_vento05, valores_vento)
    dif_vento06 = calculosDeDiferençaVento(ecdf_vento06, valores_vento)
    dif_vento07 = calculosDeDiferençaVento(ecdf_vento07, valores_vento)
    dif_vento08 = calculosDeDiferençaVento(ecdf_vento08, valores_vento)
    dif_vento09 = calculosDeDiferençaVento(ecdf_vento09, valores_vento)
    dif_vento10 = calculosDeDiferençaVento(ecdf_vento10, valores_vento)
    dif_vento11 = calculosDeDiferençaVento(ecdf_vento11, valores_vento)
    dif_vento12 = calculosDeDiferençaVento(ecdf_vento12, valores_vento)
    dif_vento13 = calculosDeDiferençaVento(ecdf_vento13, valores_vento)
    dif_vento14 = calculosDeDiferençaVento(ecdf_vento14, valores_vento)
    dif_vento15 = calculosDeDiferençaVento(ecdf_vento15, valores_vento)
    dif_vento16 = calculosDeDiferençaVento(ecdf_vento16, valores_vento)
    dif_vento17 = calculosDeDiferençaVento(ecdf_vento17, valores_vento)
    dif_vento18 = calculosDeDiferençaVento(ecdf_vento18, valores_vento)
    
    def pesos(me_rad, me_temp_min, me_temp_max, me_umid, me_temp_orv_max, me_temp_orv, me_temp_orv_min, me_bulb_seco, me_vento):
        total = ((me_rad * 12) + me_temp_min + me_temp_max + (me_umid*2) + me_temp_orv_max + (me_temp_orv*2) + me_temp_orv_min + (me_bulb_seco*2) + (me_vento*2))
        return total   
​
    peso00 = pesos(dif_rad00, dif_temp_min00, dif_temp_max00, dif_umid00, dif_temp_pont_orv_max00, dif_temp_pont_orv00, dif_temp_pont_orv_min00, dif_temp_bulb_seco00, dif_vento00)
    peso01 = pesos(dif_rad01, dif_temp_min01, dif_temp_max01, dif_umid01, dif_temp_pont_orv_max01, dif_temp_pont_orv01, dif_temp_pont_orv_min01, dif_temp_bulb_seco01, dif_vento01)
    peso02 = pesos(dif_rad02, dif_temp_min02, dif_temp_max02, dif_umid02, dif_temp_pont_orv_max02, dif_temp_pont_orv02, dif_temp_pont_orv_min02, dif_temp_bulb_seco02, dif_vento02)
    peso03 = pesos(dif_rad03, dif_temp_min03, dif_temp_max03, dif_umid03, dif_temp_pont_orv_max03, dif_temp_pont_orv03, dif_temp_pont_orv_min03, dif_temp_bulb_seco03, dif_vento03)
    peso04 = pesos(dif_rad04, dif_temp_min04, dif_temp_max04, dif_umid04, dif_temp_pont_orv_max04, dif_temp_pont_orv04, dif_temp_pont_orv_min04, dif_temp_bulb_seco04, dif_vento04)
    peso05 = pesos(dif_rad05, dif_temp_min05, dif_temp_max05, dif_umid05, dif_temp_pont_orv_max05, dif_temp_pont_orv05, dif_temp_pont_orv_min05, dif_temp_bulb_seco05, dif_vento05)
    peso06 = pesos(dif_rad06, dif_temp_min06, dif_temp_max06, dif_umid06, dif_temp_pont_orv_max06, dif_temp_pont_orv06, dif_temp_pont_orv_min06, dif_temp_bulb_seco06, dif_vento06)
    peso07 = pesos(dif_rad07, dif_temp_min07, dif_temp_max07, dif_umid07, dif_temp_pont_orv_max07, dif_temp_pont_orv07, dif_temp_pont_orv_min07, dif_temp_bulb_seco07, dif_vento07)
    peso08 = pesos(dif_rad08, dif_temp_min08, dif_temp_max08, dif_umid08, dif_temp_pont_orv_max08, dif_temp_pont_orv08, dif_temp_pont_orv_min08, dif_temp_bulb_seco08, dif_vento08)
    peso09 = pesos(dif_rad09, dif_temp_min09, dif_temp_max09, dif_umid09, dif_temp_pont_orv_max09, dif_temp_pont_orv09, dif_temp_pont_orv_min09, dif_temp_bulb_seco09, dif_vento09)
    peso10 = pesos(dif_rad10, dif_temp_min10, dif_temp_max10, dif_umid10, dif_temp_pont_orv_max10, dif_temp_pont_orv10, dif_temp_pont_orv_min10, dif_temp_bulb_seco10, dif_vento10)
    peso11 = pesos(dif_rad11, dif_temp_min11, dif_temp_max11, dif_umid11, dif_temp_pont_orv_max11, dif_temp_pont_orv11, dif_temp_pont_orv_min11, dif_temp_bulb_seco11, dif_vento11)
    peso12 = pesos(dif_rad12, dif_temp_min12, dif_temp_max12, dif_umid12, dif_temp_pont_orv_max12, dif_temp_pont_orv12, dif_temp_pont_orv_min12, dif_temp_bulb_seco12, dif_vento12)
    peso13 = pesos(dif_rad13, dif_temp_min13, dif_temp_max13, dif_umid13, dif_temp_pont_orv_max13, dif_temp_pont_orv13, dif_temp_pont_orv_min13, dif_temp_bulb_seco13, dif_vento13)
    peso14 = pesos(dif_rad14, dif_temp_min14, dif_temp_max14, dif_umid14, dif_temp_pont_orv_max14, dif_temp_pont_orv14, dif_temp_pont_orv_min14, dif_temp_bulb_seco14, dif_vento14)
    peso15 = pesos(dif_rad15, dif_temp_min15, dif_temp_max15, dif_umid15, dif_temp_pont_orv_max15, dif_temp_pont_orv15, dif_temp_pont_orv_min15, dif_temp_bulb_seco15, dif_vento15)
    peso16 = pesos(dif_rad16, dif_temp_min16, dif_temp_max16, dif_umid16, dif_temp_pont_orv_max16, dif_temp_pont_orv16, dif_temp_pont_orv_min16, dif_temp_bulb_seco16, dif_vento16)
    peso17 = pesos(dif_rad17, dif_temp_min17, dif_temp_max17, dif_umid17, dif_temp_pont_orv_max17, dif_temp_pont_orv17, dif_temp_pont_orv_min17, dif_temp_bulb_seco17, dif_vento17)
    peso18 = pesos(dif_rad18, dif_temp_min18, dif_temp_max18, dif_umid18, dif_temp_pont_orv_max18, dif_temp_pont_orv18, dif_temp_pont_orv_min18, dif_temp_bulb_seco18, dif_vento18)
​
​
    total =   [(peso00, variavel_radiação00, variavel_bulbo_seco00),
        (peso01, variavel_radiação01, variavel_bulbo_seco01),
        (peso02, variavel_radiação02, variavel_bulbo_seco02),
        (peso03, variavel_radiação03, variavel_bulbo_seco03),
        (peso04, variavel_radiação04, variavel_bulbo_seco04),
        (peso05, variavel_radiação05, variavel_bulbo_seco05),
        (peso06, variavel_radiação06, variavel_bulbo_seco06),
        (peso07, variavel_radiação07, variavel_bulbo_seco07),
        (peso08, variavel_radiação08, variavel_bulbo_seco08),
        (peso09, variavel_radiação09, variavel_bulbo_seco09),
        (peso10, variavel_radiação10, variavel_bulbo_seco10),
        (peso11, variavel_radiação11, variavel_bulbo_seco11),
        (peso12, variavel_radiação12, variavel_bulbo_seco12),
        (peso13, variavel_radiação13, variavel_bulbo_seco13),
        (peso14, variavel_radiação14, variavel_bulbo_seco14),
        (peso15, variavel_radiação15, variavel_bulbo_seco15),
        (peso16, variavel_radiação16, variavel_bulbo_seco16),
        (peso17, variavel_radiação17, variavel_bulbo_seco17),
        (peso18, variavel_radiação18, variavel_bulbo_seco18)]
    df_finais = pd.DataFrame(total, columns = ['valores','rad', 'bulbSeco'])
    final_ordem = df_finais.sort_values(by = 'valores')
    final5 = final_ordem.head(5)
    
    'melhores radiação'
    prim_ano_rad = final5['rad'].iloc[0]
    segu_ano_rad = final5['rad'].iloc[1]
    terc_ano_rad = final5['rad'].iloc[2]
    quar_ano_rad = final5['rad'].iloc[3]
    quin_ano_rad = final5['rad'].iloc[4]
​
​
    'temp med melhores'
    prim_temp_med = final5['bulbSeco'].iloc[0]
    segu_temp_med = final5['bulbSeco'].iloc[1]
    terc_temp_med = final5['bulbSeco'].iloc[2]
    quar_temp_med = final5['bulbSeco'].iloc[3]
    quin_temp_med = final5['bulbSeco'].iloc[4]
​
    'geração de dataframe com valores de x e y'
    def dataframeXeY(ecdf):
        ecdf_x = pd.DataFrame(ecdf.x, columns = ['valores_de_x'])
        ecdf_y = pd.DataFrame(ecdf.y, columns = ['valores_de_y'])
        Dataframe_ecdf = pd.concat([ecdf_x, ecdf_y], axis=1, join='inner')
        return Dataframe_ecdf
​
    rad_valores_xey = dataframeXeY(ecdf_Radiação)
    temp_media_valores_xey = dataframeXeY(ecdf_temp_bulb_seco)
    
    def valoresAbaixo33(dados):
        valores_abaixo_33 = dados.loc[(dados.valores_de_y < 0.33)]
        valores_abaixo_33 = set(valores_abaixo_33['valores_de_x'])
        return valores_abaixo_33
​
    def valoresAcima67(dados):
        rad_valores_apos_67 = dados.loc[(dados.valores_de_y > 0.67)]
        irad_valores_apos_67 = set(rad_valores_apos_67['valores_de_x'])
        return irad_valores_apos_67
    
    irad_valores_abaixo_33 = valoresAbaixo33(rad_valores_xey)
    irad_valores_acima_67 = valoresAcima67(rad_valores_xey)
​
    itemp_media_valores_abaixo_33 = valoresAbaixo33(temp_media_valores_xey)
    itemp_media_valores_acima_67 = valoresAcima67(temp_media_valores_xey)
    
    Spr = set(prim_ano_rad)
    Ssr = set(segu_ano_rad)
    Str = set(terc_ano_rad)
    Sqr = set(quar_ano_rad)
    SQr = set(quin_ano_rad)
​
    Sptme = set(prim_temp_med)
    Sstme = set(segu_temp_med)
    Sttme = set(terc_temp_med)
    Sqtme = set(quar_temp_med)
    SQtme = set(quin_temp_med)
    
    def tirarDia(dados):
        dados = dados.reset_index(level='datetm')
        dados['Day'] = dados['datetm'].dt.day
        return dados
​
​
    prim_ano_rad = tirarDia(prim_ano_rad)
    segu_ano_rad = tirarDia(segu_ano_rad)
    terc_ano_rad = tirarDia(terc_ano_rad)
    quar_ano_rad = tirarDia(quar_ano_rad)
    quin_ano_rad = tirarDia(quin_ano_rad)
​
​
    prim_temp_media = tirarDia(prim_temp_med)
    segu_temp_media = tirarDia(segu_temp_med)
    terc_temp_media = tirarDia(terc_temp_med)
    quar_temp_media = tirarDia(quar_temp_med)
    quin_temp_media = tirarDia(quin_temp_med)
    
    
    prim_temp_media['ano'] = prim_temp_media['datetm'].dt.year
    prim_ano = prim_temp_media['ano']
    prim_ano = prim_ano.iloc[0]
    segu_temp_media['ano'] = segu_temp_media['datetm'].dt.year
    segu_ano = segu_temp_media['ano']
    segu_ano = segu_ano.iloc[0]
    terc_temp_media['ano'] = terc_temp_media['datetm'].dt.year
    terc_ano = terc_temp_media['ano']
    terc_ano = terc_ano.iloc[0]
    quar_temp_media['ano'] = quar_temp_media['datetm'].dt.year
    quar_ano = quar_temp_media['ano']
    quar_ano = quar_ano.iloc[0]
    quin_temp_media['ano'] = quin_temp_media['datetm'].dt.year
    quin_ano = quin_temp_media['ano']
    quin_ano = quin_ano.iloc[0]
​
    prim_temp_media['month'] = prim_temp_media['datetm'].dt.month
    prim_mes = prim_temp_media['month']
    prim_mes = prim_mes.iloc[0]
    
    def persistenciaRadiação(dfset, anoRadiacao):
        PRa33 = irad_valores_abaixo_33.intersection(dfset)
        PRa33 = pd.DataFrame(PRa33, columns = ['glo_avg'])
        PRa33 = PRa33.max()
        prim_ano_rad1 = anoRadiacao.loc[(anoRadiacao.glo_avg) <= PRa33.glo_avg]
        prim_ano_rad1 = prim_ano_rad1.diff()
        prim_ano_radt1 = prim_ano_rad1.loc[(prim_ano_rad1.Day) == 1]
        prim_ano_radt1 = prim_ano_radt1['Day'].sum()
        return prim_ano_radt1
​
    def persistenciaTemperatura(dfset, anoTemperatura):
        PTMaa33 = itemp_media_valores_abaixo_33.intersection(dfset)
        PTMaa33 = pd.DataFrame(PTMaa33, columns = ['temp_max'])
        PTMaa33 = PTMaa33.max()
        PTMaa67 = itemp_media_valores_acima_67.intersection(dfset)
        PTMaa67 = pd.DataFrame(PTMaa67, columns = ['temp_max'])
        PTMaa67 = PTMaa67.min()
        temp_max1 = anoTemperatura.loc[(anoTemperatura.tempBulb) <= PTMaa33.temp_max]
        temp_max1 = temp_max1.diff()
        temp_max3 = anoTemperatura.loc[(anoTemperatura.tempBulb) > PTMaa67.temp_max]
        temp_max3 = temp_max3.diff()
        temp_maxt1 = temp_max1.loc[(temp_max1.Day) == 1]
        temp_maxt1 = temp_maxt1['Day'].sum()
        temp_maxt3 = temp_max3.loc[(temp_max3.Day) == 1]
        temp_maxt3 = temp_maxt3['Day'].sum()
        temp_maxtt = temp_maxt1 + temp_maxt3
        return temp_maxtt
​
​
    prim_ano_radtt = persistenciaRadiação(Spr, prim_ano_rad)
    segu_ano_radtt = persistenciaRadiação(Ssr, segu_ano_rad)
    terc_ano_radtt = persistenciaRadiação(Str, terc_ano_rad)
    quar_ano_radtt = persistenciaRadiação(Sqr, quar_ano_rad)
    quin_ano_radtt = persistenciaRadiação(SQr, quin_ano_rad)
​
    prim_temp_medtt = persistenciaTemperatura(Sptme, prim_temp_media)
    segu_temp_medtt = persistenciaTemperatura(Sstme, segu_temp_media)
    terc_temp_medtt = persistenciaTemperatura(Sttme, terc_temp_media)
    quar_temp_medtt = persistenciaTemperatura(Sqtme, quar_temp_media)
    quin_temp_medtt = persistenciaTemperatura(SQtme, quin_temp_media)
    
    prim_ano_t = prim_ano_radtt + prim_temp_medtt
    segu_ano_t = segu_ano_radtt + segu_temp_medtt 
    terc_ano_t = terc_ano_radtt + terc_temp_medtt 
    quar_ano_t = quar_ano_radtt + quar_temp_medtt 
    quin_ano_t = quin_ano_radtt + quin_temp_medtt 
​
​
    prim_valor = final5['valores'].iloc[0]
    segu_valor = final5['valores'].iloc[1]
    terc_valor = final5['valores'].iloc[2]
    quar_valor = final5['valores'].iloc[3]
    quin_valor = final5['valores'].iloc[4]
    
    final = [(prim_ano_t, prim_ano, prim_valor),
            (segu_ano_t, segu_ano, segu_valor),
            (terc_ano_t, terc_ano, terc_valor),
            (quar_ano_t, quar_ano, quar_valor),
            (quin_ano_t, quin_ano, quin_valor)]
​
    df_final = pd.DataFrame(final, columns = ['valores', 'anos', 'valoresmelhores'])
    final_ordem = df_final.sort_values(by = 'valores')
    final_ordem = final_ordem.loc[(final_ordem.valores) != 0]
    final4 = final_ordem.head(4)
    final_ordem = final4.sort_values(by = 'valoresmelhores')
    AMT = final_ordem['anos'].iloc[0]
    print('O ano metereológico típico do mes', prim_mes,', da base analisado é', AMT)
    return AMT
# Out:
#   File "<ipython-input-1-85820e14faad>", line 11
#     ​
#     ^
# SyntaxError: invalid character in identifier

# %%
## Rodar a função para todos os meses

AMT1 = AMT(df_00Jan, df_01Jan, df_02Jan, df_03Jan, df_04Jan, df_05Jan, df_06Jan, df_07Jan, df_08Jan, df_09Jan, df_10Jan, df_11Jan, df_12Jan, df_13Jan, df_14Jan, df_15Jan, df_16Jan, df_17Jan, df_18Jan, 1)
AMT2 = AMT(df_00Fev, df_01Fev, df_02Fev, df_03Fev, df_04Fev, df_05Fev, df_06Fev, df_07Fev, df_08Fev, df_09Fev, df_10Fev, df_11Fev, df_12Fev, df_13Fev, df_14Fev, df_15Fev, df_16Fev, df_17Fev, df_18Fev, 2)
AMT3 = AMT(df_00Mar, df_01Mar, df_02Mar, df_03Mar, df_04Mar, df_05Mar, df_06Mar, df_07Mar, df_08Mar, df_09Mar, df_10Mar, df_11Mar, df_12Mar, df_13Mar, df_14Mar, df_15Mar, df_16Mar, df_17Mar, df_18Mar, 3)
AMT4 = AMT(df_00Abr, df_01Abr, df_02Abr, df_03Abr, df_04Abr, df_05Abr, df_06Abr, df_07Abr, df_08Abr, df_09Abr, df_10Abr, df_11Abr, df_12Abr, df_13Abr, df_14Abr, df_15Abr, df_16Abr, df_17Abr, df_18Abr, 4)
AMT5 = AMT(df_00Mai, df_01Mai, df_02Mai, df_03Mai, df_04Mai, df_05Mai, df_06Mai, df_07Mai, df_08Mai, df_09Mai, df_10Mai, df_11Mai, df_12Mai, df_13Mai, df_14Mai, df_15Mai, df_16Mai, df_17Mai, df_18Mai, 5)
AMT6 = AMT(df_00Jun, df_01Jun, df_02Jun, df_03Jun, df_04Jun, df_05Jun, df_06Jun, df_07Jun, df_08Jun, df_09Jun, df_10Jun, df_11Jun, df_12Jun, df_13Jun, df_14Jun, df_15Jun, df_16Jun, df_17Jun, df_18Jun, 6)
AMT7 = AMT(df_00Jul, df_01Jul, df_02Jul, df_03Jul, df_04Jul, df_05Jul, df_06Jul, df_07Jul, df_08Jul, df_09Jul, df_10Jul, df_11Jul, df_12Jul, df_13Jul, df_14Jul, df_15Jul, df_16Jul, df_17Jul, df_18Jul, 7)
AMT8 = AMT(df_00Ago, df_01Ago, df_02Ago, df_03Ago, df_04Ago, df_05Ago, df_06Ago, df_07Ago, df_08Ago, df_09Ago, df_10Ago, df_11Ago, df_12Ago, df_13Ago, df_14Ago, df_15Ago, df_16Ago, df_17Ago, df_18Ago, 8)
AMT9 = AMT(df_00Set, df_01Set, df_02Set, df_03Set, df_04Set, df_05Set, df_06Set, df_07Set, df_08Set, df_09Set, df_10Set, df_11Set, df_12Set, df_13Set, df_14Set, df_15Set, df_16Set, df_17Set, df_18Set, 9)
AMT10 = AMT(df_00Out, df_01Out, df_02Out, df_03Out, df_04Out, df_05Out, df_06Out, df_07Out, df_08Out, df_09Out, df_10Out, df_11Out, df_12Out, df_13Out, df_14Out, df_15Out, df_16Out, df_17Out, df_18Out, 10)
AMT11 = AMT(df_00Nov, df_01Nov, df_02Nov, df_03Nov, df_04Nov, df_05Nov, df_06Nov, df_07Nov, df_08Nov, df_09Nov, df_10Nov, df_11Nov, df_12Nov, df_13Nov, df_14Nov, df_15Nov, df_16Nov, df_17Nov, df_18Nov, 11)
AMT12 = AMT(df_00Dez, df_01Dez, df_02Dez, df_03Dez, df_04Dez, df_05Dez, df_06Dez, df_07Dez, df_08Dez, df_09Dez, df_10Dez, df_11Dez, df_12Dez, df_13Dez, df_14Dez, df_15Dez, df_16Dez, df_17Dez, df_18Dez, 12)

# %%
Base = str(input('qual a base? '))
estado = str(input('qual a base? '))

dfAmt = [(Base, estado, AMT1, AMT2, AMT3, AMT4, AMT5, AMT6, AMT7, AMT8, AMT9, AMT10, AMT11, AMT12)]
DfAmt = pd.DataFrame(dfAmt, columns= ['Base', 'Estado', 'Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])

##A tabela foi salva no meu google drive
AMTpassados = pd.read_csv('C:/Users/pedro/OneDrive/Documentos/projeto python/AMT2.csv', sep = ',')
x = pd.concat([AMTpassados, DfAmt])
x.to_csv(r'C:/Users/pedro/OneDrive/Documentos/projeto python/AMT2.csv', index = False, header=True)
